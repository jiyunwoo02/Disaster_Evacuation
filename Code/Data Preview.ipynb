# %%
import pandas as pd

# %%
df = pd.read_csv('민방위.csv')
df
# Out:
#            민방위대피시설명                                   소재지도로명주소  \
# 0      광주지방노동청 전주지청  전라북도 전주시 덕진구 건산로 251 (인후동1가, 광주지방노동청전주지청)
# 1           KT 임실지사             전라북도 임실군 임실읍 봉황로 143 (K.T 임실점)
# 2      가톨릭대학병원 장례식장    대구광역시 남구 두류공원로17길 33 (대명동, 대구가톨릭의과대학병원)
# 3            강동고등학교                   서울특별시 강동구 구천면로 572 (상일동)
# 4              강릉교회                      강원도 강릉시 해안로 333 (강문동)
# ...             ...                                        ...
# 17098     호암(진도아파트)            충청북도 충주시 호암중앙2로 27 (호암동, 진도아파트)
# 17099     호암(부강아파트)            충청북도 충주시 호암중앙2로 31 (호암동, 부강아파트)
# 17100   호암(예성세경아파트)             충청북도 충주시 신촌2길 2 (호암동, 예성세경아파트)
# 17101   호암(현대호반아파트)            충청북도 충주시 신촌2길 29 (호암동, 현대호반아파트)
# 17102          효성타운              대구광역시 남구 효성중앙길 37 (봉덕동, 효성타운)
#
#                       소재지지번주소          경도         위도  민방위대피시설면적  \
# 0                    807번지 8호  127.164306  35.835253     2488.0
# 1                     KT 임실지사  127.278528  35.613694      720.0
# ...

# %%
df = df.iloc[0:8501]
df
# Out:
#                        민방위대피시설명                                   소재지도로명주소  \
# 0                  광주지방노동청 전주지청  전라북도 전주시 덕진구 건산로 251 (인후동1가, 광주지방노동청전주지청)
# 1                       KT 임실지사             전라북도 임실군 임실읍 봉황로 143 (K.T 임실점)
# 2                  가톨릭대학병원 장례식장    대구광역시 남구 두류공원로17길 33 (대명동, 대구가톨릭의과대학병원)
# 3                        강동고등학교                   서울특별시 강동구 구천면로 572 (상일동)
# 4                          강릉교회                      강원도 강릉시 해안로 333 (강문동)
# ...                         ...                                        ...
# 8496  동래한양아파트1,2,3,4,5,6,7,8,9동          부산광역시 동래구 충렬대로 314 (낙민동, 동래한양아파트)
# 8497             부산 도시철도4호선 낙민역      부산광역시 동래구 충렬대로 지하 285 (낙민동, 도시철도 낙민역)
# 8498            동래우성아파트101,102동             부산광역시 동래구 안남로 9 (낙민동, 동래우성아파트)
# 8499            중앙하이츠2차202,203동                     부산광역시 동래구 안남로 36 (낙민동)
# 8500              중앙하이츠101,102동            부산광역시 동래구 안남로31번길 10 (중앙하이츠아파트)
#
#                      소재지지번주소          경도         위도  민방위대피시설면적  \
# ...

# %%
df2 = pd.read_csv('대피장소.csv')
df2
# Out:
#       ID SIDO_NAME SIGUNGU_NAME   REMARKS         SHEL_NM  \
# 0     순번       시도명         시군구명       지역명            대피소명
# 1    352      경상북도        포항시북구  방어지구(포항)         월포백번횟집앞
# 2    455      경상북도          영덕군      삼사지구         삼사공원입구1
# 3    454      경상북도          영덕군     사진3지구           마을뒤야산
# 4    453      경상북도          영덕군     사진2지구          마을뒤 공터
# ..   ...       ...          ...       ...             ...
# 96   393      경상북도          경주시      대본지구  대본3리 마을회관 앞 공터
# 97   392      경상북도          경주시      대본지구      감포관광단지 주차장
# 98   391      경상북도          경주시      나정지구       전촌1리 마을회관
# 99   390      경상북도          경주시      나정지구   시드니 낚시마트 뒤 야산
# 100  483      경상북도          영덕군      하저지구         하저문화마을뒤
#
#                      ADDRESS SHEL_AV LENTH  \
# 0                         주소  수용가능인원    길이
# 1    경상북도 포항시 북구 청하면 방어리 산16     200   690
# 2       경상북도 영덕군 강구면 해상공원길 9     500   250
# 3       경상북도 영덕군 영해면 공수진길 44     100   150
# 4     경상북도 영덕군 영해면 괴시사진길 319     150   150
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8501 entries, 0 to 8500
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   민방위대피시설명   8501 non-null   object
#  1   소재지도로명주소   8471 non-null   object
#  2   소재지지번주소    8501 non-null   object
#  3   경도         8501 non-null   float64
#  4   위도         8501 non-null   float64
#  5   민방위대피시설면적  8501 non-null   float64
#  6   지번주소_정제    8501 non-null   object
#  7   도로명주소_정제   8471 non-null   object
#  8   지상층수       8058 non-null   float64
#  9   지하층수       8058 non-null   float64
#  10  건물유형       8058 non-null   object
#  11  세분류        8501 non-null   object
#  12  대분류        8501 non-null   object
#  13  지역         8501 non-null   object
# dtypes: float64(5), object(9)
# memory usage: 929.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             101 non-null    object
#  1   SIDO_NAME      101 non-null    object
#  2   SIGUNGU_NAME   101 non-null    object
#  3   REMARKS        101 non-null    object
#  4   SHEL_NM        101 non-null    object
#  5   ADDRESS        101 non-null    object
#  6   SHEL_AV        101 non-null    object
#  7   LENTH          101 non-null    object
#  8   SHEL_DIV_TYPE  101 non-null    object
#  9   SEISMIC        5 non-null      object
#  10  HEIGHT         101 non-null    object
#  11  MANAGE_GOV     101 non-null    object
#  12  TEL            101 non-null    object
#  13  DT_REGT        101 non-null    object
#  14  DEL_YN         101 non-null    object
#  15  LON            100 non-null    float64
#  16  LAT            100 non-null    float64
# dtypes: float64(2), object(15)
# ...

# %%
df.shape
# Out:
# (8501, 14)

# %%
df2.shape
# Out:
# (101, 17)

# %%
df2 = df2.rename(columns={'LON':'경도'})
df2 = df2.rename(columns={'LAT':'위도'})

df2 = df2.drop(columns={'ID', 'LENTH','SHEL_DIV_TYPE','SEISMIC','HEIGHT','DT_REGT','DEL_YN'})

# %%
df2
# Out:
#     SIDO_NAME SIGUNGU_NAME   REMARKS         SHEL_NM                  ADDRESS  \
# 0         시도명         시군구명       지역명            대피소명                       주소
# 1        경상북도        포항시북구  방어지구(포항)         월포백번횟집앞  경상북도 포항시 북구 청하면 방어리 산16
# 2        경상북도          영덕군      삼사지구         삼사공원입구1     경상북도 영덕군 강구면 해상공원길 9
# 3        경상북도          영덕군     사진3지구           마을뒤야산     경상북도 영덕군 영해면 공수진길 44
# 4        경상북도          영덕군     사진2지구          마을뒤 공터   경상북도 영덕군 영해면 괴시사진길 319
# ..        ...          ...       ...             ...                      ...
# 96       경상북도          경주시      대본지구  대본3리 마을회관 앞 공터   경상북도 경주시 감포읍 대본리 606-6
# 97       경상북도          경주시      대본지구      감포관광단지 주차장    경상북도 경주시 감포읍 대본리 1247
# 98       경상북도          경주시      나정지구       전촌1리 마을회관   경상북도 경주시 감포읍 천촌리 532-1
# 99       경상북도          경주시      나정지구   시드니 낚시마트 뒤 야산   경상북도 경주시 감포읍 천촌리 105-2
# 100      경상북도          영덕군      하저지구         하저문화마을뒤  경상북도 영덕군 강구면 하저1길 21-34
#
# ...

# %%
import pandas as pd

df1 = df.merge(df2, left_index=True, right_index=True)

# %%
df1
# Out:
#          민방위대피시설명                                   소재지도로명주소  \
# 0    광주지방노동청 전주지청  전라북도 전주시 덕진구 건산로 251 (인후동1가, 광주지방노동청전주지청)
# 1         KT 임실지사             전라북도 임실군 임실읍 봉황로 143 (K.T 임실점)
# 2    가톨릭대학병원 장례식장    대구광역시 남구 두류공원로17길 33 (대명동, 대구가톨릭의과대학병원)
# 3          강동고등학교                   서울특별시 강동구 구천면로 572 (상일동)
# 4            강릉교회                      강원도 강릉시 해안로 333 (강문동)
# ..            ...                                        ...
# 96     토성면 주민대피시설                     강원도 고성군 토성면 학사촌길 지하 49
# 97      켄싱턴리조트 지하           강원도 고성군 토성면 동해대로 4800-0 (캔싱턴리조트)
# 98      배봉리 주민대피소                       강원도 고성군 현내면 배봉길 12-8
# 99      현내 주민대피시설               강원도 고성군 현내면 한나루로 67 (현내면사무소)
# 100      금강산콘도 지하                       강원도 고성군 현내면 금강산로 416
#
#                   소재지지번주소        경도_x       위도_x  민방위대피시설면적  \
# 0                807번지 8호  127.164306  35.835253     2488.0
# 1                 KT 임실지사  127.278528  35.613694      720.0
# ...

# %%
df1.columns
# Out:
# Index(['민방위대피시설명', '소재지도로명주소', '소재지지번주소', '경도_x', '위도_x', '민방위대피시설면적',
#        '지번주소_정제', '도로명주소_정제', '지상층수', '지하층수', '건물유형', '세분류', '대분류', '지역',
#        'SIDO_NAME', 'SIGUNGU_NAME', 'REMARKS', 'SHEL_NM', 'ADDRESS', 'SHEL_AV',
#        'MANAGE_GOV', 'TEL', '경도_y', '위도_y'],
#       dtype='object')

# %%
import pandas as pd

merged_df = pd.merge(df, df2, on='경도', suffixes=('_df', '_df2'))
merged_df
# Out:
# Empty DataFrame
# Columns: [민방위대피시설명, 소재지도로명주소, 소재지지번주소, 경도, 위도_df, 민방위대피시설면적, 지번주소_정제, 도로명주소_정제, 지상층수, 지하층수, 건물유형, 세분류, 대분류, 지역, SIDO_NAME, SIGUNGU_NAME, REMARKS, SHEL_NM, ADDRESS, SHEL_AV, MANAGE_GOV, TEL, 위도_df2]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# -> 겹치는 데이터 없음

# %%
merged_df = df.merge(df2, on='경도', how='inner')
merged_df
# Out:
# Empty DataFrame
# Columns: [민방위대피시설명, 소재지도로명주소, 소재지지번주소, 경도, 위도_x, 민방위대피시설면적, 지번주소_정제, 도로명주소_정제, 지상층수, 지하층수, 건물유형, 세분류, 대분류, 지역, SIDO_NAME, SIGUNGU_NAME, REMARKS, SHEL_NM, ADDRESS, SHEL_AV, MANAGE_GOV, TEL, 위도_y]
# Index: []
#
# [0 rows x 23 columns]

# %%
merged_df = df.merge(df2, on='위도', how='inner')
merged_df
# Out:
# Empty DataFrame
# Columns: [민방위대피시설명, 소재지도로명주소, 소재지지번주소, 경도_x, 위도, 민방위대피시설면적, 지번주소_정제, 도로명주소_정제, 지상층수, 지하층수, 건물유형, 세분류, 대분류, 지역, SIDO_NAME, SIGUNGU_NAME, REMARKS, SHEL_NM, ADDRESS, SHEL_AV, MANAGE_GOV, TEL, 경도_y]
# Index: []
#
# [0 rows x 23 columns]

# %%
data = pd.read_csv('민방위.csv')
data
# Out:
#            민방위대피시설명                                   소재지도로명주소  \
# 0      광주지방노동청 전주지청  전라북도 전주시 덕진구 건산로 251 (인후동1가, 광주지방노동청전주지청)
# 1           KT 임실지사             전라북도 임실군 임실읍 봉황로 143 (K.T 임실점)
# 2      가톨릭대학병원 장례식장    대구광역시 남구 두류공원로17길 33 (대명동, 대구가톨릭의과대학병원)
# 3            강동고등학교                   서울특별시 강동구 구천면로 572 (상일동)
# 4              강릉교회                      강원도 강릉시 해안로 333 (강문동)
# ...             ...                                        ...
# 17098     호암(진도아파트)            충청북도 충주시 호암중앙2로 27 (호암동, 진도아파트)
# 17099     호암(부강아파트)            충청북도 충주시 호암중앙2로 31 (호암동, 부강아파트)
# 17100   호암(예성세경아파트)             충청북도 충주시 신촌2길 2 (호암동, 예성세경아파트)
# 17101   호암(현대호반아파트)            충청북도 충주시 신촌2길 29 (호암동, 현대호반아파트)
# 17102          효성타운              대구광역시 남구 효성중앙길 37 (봉덕동, 효성타운)
#
#                       소재지지번주소          경도         위도  민방위대피시설면적  \
# 0                    807번지 8호  127.164306  35.835253     2488.0
# 1                     KT 임실지사  127.278528  35.613694      720.0
# ...

# %%
merged_df = data.merge(df2, on='위도', how='inner')
merged_df
# Out:
# Empty DataFrame
# Columns: [민방위대피시설명, 소재지도로명주소, 소재지지번주소, 경도_x, 위도, 민방위대피시설면적, 지번주소_정제, 도로명주소_정제, 지상층수, 지하층수, 건물유형, 세분류, 대분류, 지역, SIDO_NAME, SIGUNGU_NAME, REMARKS, SHEL_NM, ADDRESS, SHEL_AV, MANAGE_GOV, TEL, 경도_y]
# Index: []
#
# [0 rows x 23 columns]

# %%
merged_df = data.merge(df2, on='경도', how='inner')
merged_df
# Out:
#          민방위대피시설명                                소재지도로명주소  \
# 0  서부1차@ 113동 지하실  울산광역시 동구 방어진순환도로 995 (서부동, 현대패밀리서부아파트)
#
#                  소재지지번주소          경도       위도_x  민방위대피시설면적  \
# 0  울산광역시 동구 서부동 257번지 4호  129.431069  35.527939      739.2
#
#                 지번주소_정제              도로명주소_정제  지상층수  지하층수  ...     지역  \
# 0  울산광역시 동구 서부동 257-4번지  울산광역시 동구 방어진순환도로 995  15.0   1.0  ...  울산광역시
#
#   SIDO_NAME SIGUNGU_NAME REMARKS    SHEL_NM               ADDRESS SHEL_AV  \
# 0      경상북도          영덕군    노물지구  구)보건소 맞은편  경상북도 영덕군 영덕읍 노물1길 15      35
#
#   MANAGE_GOV           TEL       위도_y
# 0      47770  054-730-6521  36.446812
#
# [1 rows x 23 columns]

# %% [markdown]
# https://www.safekorea.go.kr/idsiSFK/neo/sfk/cs/contents/civil_defense/SDIJKM1402.html?menuSeq=57&

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -> 노가다로 찾을 수도 있지만 위 사례처럼 신주소로 변환되어서 못 찾을 경우도 있을 거 같음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -> [전라북도 임실군 임실읍...] 찾으려는 주소 자체가 없음,
